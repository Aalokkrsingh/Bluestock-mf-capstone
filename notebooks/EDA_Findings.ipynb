# %% [markdown]
# ### **Comprehensive Exploratory Data Analysis (EDA) Summary: Key Insights**
#
# * **Dominant Retail Market Anchor:** SBI Mutual Fund stands as the undisputed industry leader across the evaluated 4-year horizon, completely outpacing competitors and successfully breaching the historic Rs. 12.5 Lakh Crore Assets Under Management (AUM) milestone by 2025.
# * **Top-Weighted Industry Oligopoly:** The Indian asset management landscape exhibits heavy structural concentration, where the "Big Three" players (SBI, ICICI Prudential, and HDFC) command a massive market share, leaving a significant capital asset gap between themselves and the remaining Top 10 AMCs.
# * **Universal Macroeconomic Growth:** Every single asset management company in the Top 10 segment experienced consistent Year-Over-Year (YoY) AUM expansion throughout the 2022–2025 timeframe, showing zero systemic down-years despite temporary intermediate market disruptions.
# * **The 2024–2025 Retail Surging Vector:** The absolute velocity of capital accumulation across nearly all AMCs was steepest during the 2024–2025 window, signaling an unprecedented influx of retail capital and pointing toward a massive underlying domestic market rally.
# * **Deepening Equity Savings Culture:** Monthly Systematic Investment Plan (SIP) inflows displayed structural resilience, maintaining a steady multi-year upward trajectory that peaked at a historic record milestone of Rs. 31,002 Crore in gross monthly contributions in December 2025.
# * **Habitual Investment Over Market Timing:** Unlike unpredictable lump-sum allocations, the steady, uninterrupted rise in monthly SIP trends confirms a highly disciplined, compounding savings habit among individual retail investors that persists independently of short-term market corrections.
# * **Severe Scaling Distortions from Liquid Funds:** Monthly sector-wise transaction analysis reveals that liquid categories completely dominate the gross net-inflows (averaging Rs. 30,000 to Rs. 40,000 Crore monthly), causing massive color scale distortions in primary financial heatmaps until isolated.
# * **Aggressive Growth Asset Appetite:** Once institutional liquid funds are excluded, aggressive equity instruments—specifically Sectoral/Thematic and Mid-Cap fund variants—emerge as the primary investment preferences for active retail wealth-building strategies.
# * **Accelerated Investor Account Expansion:** The overall ecosystem footprint experienced a massive structural shift as total active retail investor folios grew linearly from 13.26 Crore in January 2022 to a terminal peak of 26.12 Crore in December 2025, matching a 100% capacity double.
# * **Decoupled Pricing Vector Footprint:** Pairwise continuous daily returns tracking across core large-cap funds generated flat Pearson correlation coefficients ($r \approx 0.04$) instead of expected historical markers ($r \ge 0.85$), proving that while data pipelines run flawless engineering steps, the baseline tracking numbers utilize randomized simulated mock assets.
